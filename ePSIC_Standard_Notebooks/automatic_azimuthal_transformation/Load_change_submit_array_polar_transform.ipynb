# %% [markdown]
# In this notebook one can:
# - load a notebook's settings as a dictionary
# - change it
# - save it as a new notebook
# - submit it as an array job to SLURM cluster.

# %%
import sys
sys.path.append('/dls_sw/e02/software/epsic_tools')
import epsic_tools.api as ep
import pprint
import re
import subprocess
import os
import subprocess
import glob
import time

year = '2024'
session = 'mg37402-1'
sub_folder = 'FAPI_DMF_DMSO_MACl'
au_calib_folder = 'Au_xgrating'
au_calib_path = '/dls/e02/data/' + year + '/' + session + '/processing/Merlin/' + au_calib_folder

# %%
current = time.strftime("%s%s%s_%s%s%s"%(time.gmtime()[0], 
                               time.gmtime()[1], 
                               time.gmtime()[2],
                              time.gmtime()[3],
                              time.gmtime()[4],
                              time.gmtime()[5]))

starting_notebook_path = os.getcwd() #'/dls/science/groups/e02/Sample_data/Test_data_ePSIC_User_notebooks/scripts_folder'
starting_notebook_name = 'template_BraggAnalysis-submit'
nb = ep.notebook_utils.NotebookHelper(starting_notebook_path, starting_notebook_name)

# %%
old_settings = nb.get_settings(1) # settings should be cell index 1
old_settings = old_settings.split(' ')
old_keys = [i.split('=')[0] for i in old_settings]
old_vals = [i.split('=')[1] for i in old_settings]
old_dict = dict(zip(old_keys, old_vals))
pprint.pprint(old_dict)
# Out:
# {'Au_calib_path': '/dls/e02/data/2024/mg37302-1/processing/Merlin/Au_xgrating',
#  'bin_factor': '2',
#  'crop_q': '',
#  'fill_cross': '0',
#  'hot_pix_thresh': '0.1',
#  'load_prepared_data': '0',
#  'peak_finding_minAbsoluteIntensity': '0.25',
#  'peak_finding_minPeakSpacing': '5',
#  'prepared_data_path': '',
#  'probe_kernel_post': '5',
#  'probe_kernel_pre': '0.5',
#  'probe_path': '',
#  'raw_data_path': '/dls/e02/data/2024/mg37302-1/processing/Merlin/SP41/20240418_151824/20240418_151824_data.hdf5',
#  'save_path_name': 'manual_test',
#  'syn_probe_rad': '4',
#  'syn_probe_width': '4',
#  'synthetic_probe': '1',
#  'v_max': '0.99',
#  'v_min': '0.01'}

# %%
# def find_hdf5_files(root_dir):
#     hdf5_files = []
#     # Loop through each subdirectory in the root directory
#     for subfolder in os.listdir(root_dir):
#         # Check if the subfolder matches the 'SPXX' pattern
#         if subfolder.startswith("Li_metal"):
#             spxx_path = os.path.join(root_dir, subfolder)
#             # Loop through each dataset subfolder inside the SPXX directory
#             for dataset_subfolder in os.listdir(spxx_path):
#                 dataset_path = os.path.join(spxx_path, dataset_subfolder)
#                 # Check for .hdf5 files in the dataset subfolder
#                 for file in os.listdir(dataset_path):
#                     if file.endswith('.hdf5'):
#                         # Append the full path of the .hdf5 file
#                         hdf5_files.append(os.path.join(dataset_path, file))
#     return hdf5_files

# Specify the root directory for the Merlin folders
dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_111459/20240619_111459_data.hdf5

# %%
# make some changes in new setting
# log files from the cluster jobs and the bash script will be saved here:
code_path = merlin_root + '/cluster_logs'
if not os.path.exists(code_path):
    os.mkdir(code_path)
concurrent_jobs = 2 #Integer number of concurrent jobs to run in the array

new_notebook_paths_list = []
for file in hdf5_file_paths:
    # update the settings
    new_setting = old_dict.copy()
    new_setting['crop_q'] = ''
    new_setting['raw_data_path'] = file
    new_setting['save_path_name'] = 'cluster_processed'
    new_setting['Au_calib_path'] = au_calib_path
    #pprint.pprint(new_setting)

    save_path = os.path.join(os.path.dirname(file), new_setting['save_path_name'])
    #print(save_path)
    if not os.path.exists(save_path):
        os.mkdir(save_path)

    new_notebook_path = os.path.join(save_path, 'submitted_notebook.ipynb')
    nb.set_settings(new_setting, new_notebook_path)
    print(f'new notebook path: {new_notebook_path}')
    new_notebook_paths_list.append(new_notebook_path)

note_book_path_file = os.path.join(code_path, 'notebook_list.txt')
with open (note_book_path_file, 'a') as f:
    f.write(
        '\n'.join(new_notebook_paths_list)
    )

bash_script_path = os.path.join(code_path, 'cluster_submit.sh')
with open (bash_script_path, 'a') as f:
    f.write('''#!/usr/bin/env bash
#SBATCH --partition cs04r
#SBATCH --job-name epsic_notebook
#SBATCH --time 05:00:00
#SBATCH --nodes 1
#SBATCH --gpus-per-node 0
#SBATCH --tasks-per-node 1
#SBATCH --mem 128G
'''
f"#SBATCH --array=0-{len(new_notebook_paths_list)-1}%{int(concurrent_jobs)}\n"
f"#SBATCH --error={code_path}{os.sep}logs_{current}{os.sep}error_%j.out\n"
f"#SBATCH --output={code_path}{os.sep}logs_{current}{os.sep}output_%j.out\n"
f"module load python/epsic3.10\n"
f"mapfile -t paths_array < {note_book_path_file}\n"
'''
echo ${paths_array[$SLURM_ARRAY_TASK_ID]}
jupyter nbconvert --to notebook --inplace --ClearMetadataPreprocessor.enabled=True ${paths_array[$SLURM_ARRAY_TASK_ID]}
jupyter nbconvert --to notebook --allow-errors --execute ${paths_array[$SLURM_ARRAY_TASK_ID]}

'''
           )
        
sshProcess = subprocess.Popen(['ssh',
                               '-tt',
                               'wilson'],
                               stdin=subprocess.PIPE, 
                               stdout = subprocess.PIPE,
                               universal_newlines=True,
                               bufsize=0)
sshProcess.stdin.write("ls .\n")
sshProcess.stdin.write("echo END\n")
sshProcess.stdin.write(f"sbatch {bash_script_path}\n")
sshProcess.stdin.write("uptime\n")
sshProcess.stdin.write("logout\n")
sshProcess.stdin.close()


for line in sshProcess.stdout:
    if line == "END\n":
        break
    print(line,end="")

#to catch the lines up to logout
for line in  sshProcess.stdout: 
    print(line,end="")
# Out:
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_174052/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_174713/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_174824/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_174939/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_175050/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_175159/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_175412/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_175537/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_175805/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_175917/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_180026/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_180130/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_180241/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_180349/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_180501/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_180653/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_180804/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_181733/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_181843/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_181954/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_182145/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_182254/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_182404/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_184914/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_185033/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_185140/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_185249/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_185355/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_185503/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_185619/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_185726/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_185844/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_185954/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_190102/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_190214/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_190324/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_190434/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_190812/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_191037/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240618_191238/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_091443/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_091553/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_091706/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_091815/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_092128/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_092242/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_092348/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_092457/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_092608/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_092720/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_092830/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_092943/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_093053/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_093218/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_093340/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_100640/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_100852/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_101055/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_101256/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_101457/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_101701/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_101900/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_102103/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_102301/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_102503/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_102703/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_102909/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_103109/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_103319/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_103530/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_103728/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_104021/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_104223/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_104423/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_104621/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_104824/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_105025/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_105238/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_105437/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_105638/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_105850/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_110101/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_110213/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_110321/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_110430/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_110538/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_110648/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_110800/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_110909/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_111018/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_111126/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_111238/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_111345/cluster_processed/submitted_notebook.ipynb
# new notebook path: /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/20240619_111459/cluster_processed/submitted_notebook.ipynb
#
#  _______   __        ______         __    __  _______    ______
# |       \ |  \      /      \       |  \  |  \|       \  /      \
# | $$$$$$$\| $$     |  $$$$$$\      | $$  | $$| $$$$$$$\|  $$$$$$\
# | $$  | $$| $$     | $$___\$$      | $$__| $$| $$__/ $$| $$   \$$
# | $$  | $$| $$      \$$    \       | $$    $$| $$    $$| $$
# | $$  | $$| $$      _\$$$$$$\      | $$$$$$$$| $$$$$$$ | $$   __
# | $$__/ $$| $$_____|  \__| $$      | $$  | $$| $$      | $$__/  \
# | $$    $$| $$     \\$$    $$      | $$  | $$| $$       \$$    $$
#  \$$$$$$$  \$$$$$$$$ \$$$$$$        \$$   \$$ \$$        \$$$$$$
#
# Welcome To Wilson - The DLS Slurm Cluster
# For Help or Support - Visit: https://schelpdesk.diamond.ac.uk
#
# Please Refrain From Running Any Tasks Directly On This Node - It Is A Submission Node Only
#
# For jobs needing to access the fast ethernet filesystem please use the cs04r partition, for the Infiniband filesystem please use the cs05r partition status
#
# To get an interactive session on a cs04r partition node enter "iact02", for a cs05r partition node enter "iact03"
# Register this system with Red Hat Insights: insights-client --register
# Create an account or view all your systems at https://red.ht/insights-dashboard
# Last login: Wed Jul  3 10:27:33 2024 from cs05r-sc-cloud-07.diamond.ac.uk
#
# ls .
# echo END
# sbatch /dls/e02/data/2024/mg37402-1/processing/Merlin/FAPI_DMF_DMSO_MACl/cluster_logs/cluster_submit.sh
# uptime
# logout
# [hgl95221@cs04r-sc-vserv-300 ~]$ ls .
# DAWN_2.32  DAWN_2.34  Documents  Music  Pictures        Public     Videos
# DAWN_2.33  Desktop    Downloads  perl5  privatemodules  Templates
# [hgl95221@cs04r-sc-vserv-300 ~]$ echo END
# [hgl95221@cs04r-sc-vserv-300 ~]$ sbatch /dls/e02/data/2024/mg37402-1/processing/M
# Merlin/FAPI_DMF_DMSO_MACl/cluster_logs/cluster_submit.sh
# Submitted batch job 9512250
# [hgl95221@cs04r-sc-vserv-300 ~]$ uptime
#  11:10:15 up 22:08, 30 users,  load average: 2.73, 2.84, 2.99
# [hgl95221@cs04r-sc-vserv-300 ~]$ logout
# Connection to wilson closed.
